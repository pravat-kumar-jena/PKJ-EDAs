# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('E:\daily_Military equipment_loss_count.csv')

# %%
df
# Out:
#      Unnamed: 0        date  day  aircraft  helicopter  tank   APC  \
# 0             0  2022-02-25    2        10           7    80   516
# 1             1  2022-02-26    3        27          26   146   706
# 2             2  2022-02-27    4        27          26   150   706
# 3             3  2022-02-28    5        29          29   150   816
# 4             4  2022-03-01    6        29          29   198   846
# ..          ...         ...  ...       ...         ...   ...   ...
# 222         222  2022-10-05  224       266         232  2435  5038
# 223         223  2022-10-06  225       266         232  2449  5064
# 224         224  2022-10-07  226       266         233  2466  5093
# 225         225  2022-10-08  227       266         234  2472  5111
# 226         226  2022-10-09  228       266         235  2486  5133
#
#      field artillery  MRL  drone  naval ship  anti-aircraft warfare  \
# 0                 49    4      0           2                      0
# ...

# %%
# Bar graph
sns.barplot(df['date'],df['aircraft'])
# Out:
# E:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='date', ylabel='aircraft'>

# %%
# Histogram graph(for single column distribution)
sns.distplot(df['field artillery'])
# Out:
# <AxesSubplot:xlabel='field artillery', ylabel='Density'>

# %%
# counts
fig, ax = plt.subplots()


Accessories= ['aircraft', 'helicopter', 'tank', 'anti-aircraft warfacce']
counts = [266, 235, 2786, 180]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(Accessories, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('loss')
ax.set_xlabel('Military accessories')
# Out:
# Text(0.5, 0, 'Military accessories')

# %%
# jointplot(mora than one columns)
sns.jointplot(df['helicopter'],df['day'])
# Out:
# E:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# mora than one columns
sns.jointplot(df['helicopter'],df['day'],kind="hex")
# Out:
# E:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(df[['aircraft','tank','helicopter']])

# %%
sns.stripplot(['helicopter'],['aircraft'])
# Out:
# E:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.pointplot(df['helicopter'],df['day'])
# Out:
# E:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='helicopter', ylabel='day'>

# %%
sns.countplot(df['helicopter'])
# Out:
# E:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='helicopter', ylabel='count'>

# %%
sns.boxplot(df['helicopter'],df['day'])
# Out:
# E:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='helicopter', ylabel='day'>
